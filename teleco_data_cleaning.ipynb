# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
#Reading in the telecom data using the .read_csv method in pandas
telecom_data = pd.read_csv('telecom_data.csv')

# %%
#getting the top 5 records of the telecom data
telecom_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
#getting the column names of the telecom datasets
telecom_data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#size of the dataset(ie rows and columns)
telecom_data.shape
# Out:
# (7043, 21)

# %%
#Data types of the various columns
telecom_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#getting descriptive statistics of the numerical columns
telecom_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
telecom_data.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# getting the probabilities of the categorical variables
telecom_data.Churn.value_counts(normalize=True)
# Out:
# No     0.73463
# Yes    0.26537
# Name: Churn, dtype: float64

# %%
telecom_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# Data casting

# %%
#converting the datatype of the totalCharges column to a float datatype
telecom_data['TotalCharges'] = pd.to_numeric(telecom_data.TotalCharges, errors='coerce')
telecom_data.TotalCharges.dtype
# Out:
# dtype('float64')

# %%
#getting the nthe number of null rows in the TotalCharges column
nan = telecom_data.loc[telecom_data.TotalCharges.isnull() == True]
nan.shape
# Out:
# (11, 21)

# %%
'''since the proportion of the number of null records is having a 0.15% proportion to the real datasets, 
then we drop the null rows'''
telecom_data.dropna(inplace=True, how='any')

# %%
telecom_data.shape
# Out:
# (7032, 21)

# %%
#Getting all columns in the dataset
pd.set_option('display.max_columns', None)
#fractional part of the dataset
telecom_data.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3948  4355-CVPVS  Female              0     Yes        Yes      56
# 1542  9798-OPFEM  Female              0      No         No      46
# 4862  3721-CNEYS  Female              0      No         No       2
# 6617  8822-KNBHV  Female              0      No         No      48
# 3993  9769-TSBZE  Female              0      No        Yes      70
# 5342  3521-SYVOR  Female              0      No         No      37
# 5557  6918-UMQCG  Female              0      No         No       5
# 2105  0925-VYDLG  Female              0      No         No       3
# 3061  8118-LSUEL    Male              1      No         No      23
# 6613  9770-LXDBK  Female              0      No         No       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 3948          Yes            No     Fiber optic                   No
# 1542          Yes            No              No  No internet service
# 4862          Yes            No     Fiber optic                   No
# 6617          Yes           Yes             DSL                  Yes
# 3993          Yes           Yes             DSL                  Yes
# 5342          Yes            No             DSL                   No
# 5557          Yes            No     Fiber optic                   No
# 2105          Yes           Yes     Fiber optic                   No
# 3061          Yes           Yes     Fiber optic                   No
# 6613          Yes            No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 3948                   No                   No                   No
# 1542  No internet service  No internet service  No internet service
# 4862                   No                   No                   No
# 6617                  Yes                  Yes                   No
# 3993                  Yes                   No                  Yes
# 5342                   No                   No                   No
# 5557                   No                   No                   No
# 2105                   No                   No                   No
# 3061                  Yes                  Yes                   No
# 6613  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 3948                  Yes                  Yes        One year
# 1542  No internet service  No internet service        Two year
# 4862                   No                   No  Month-to-month
# 6617                  Yes                  Yes        One year
# 3993                   No                   No        Two year
# 5342                  Yes                  Yes  Month-to-month
# 5557                  Yes                   No  Month-to-month
# 2105                   No                   No  Month-to-month
# 3061                  Yes                  Yes  Month-to-month
# 6613  No internet service  No internet service  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 3948               No  Bank transfer (automatic)           88.90
# 1542              Yes           Electronic check           21.10
# 4862              Yes           Electronic check           70.95
# 6617              Yes    Credit card (automatic)           83.45
# 3993               No           Electronic check           66.00
# 5342              Yes           Electronic check           64.75
# 5557               No           Electronic check           80.20
# 2105               No           Electronic check           75.25
# 3061              Yes           Electronic check          106.40
# 6613               No               Mailed check           20.40
#
#       TotalCharges Churn
# 3948       4968.00    No
# 1542        937.10    No
# 4862        137.95   Yes
# 6617       3887.85    No
# 3993       4891.50    No
# 5342       2345.20   Yes
# 5557        384.25    No
# 2105        242.00   Yes
# 3061       2483.50   Yes
# 6613         63.15    No

# %%
#recalculating the totalCharges column to make it equal the tenure times the MonthlyCharges
telecom_data.TotalCharges = telecom_data['tenure'] * telecom_data['MonthlyCharges']
telecom_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1936.30
# 2              Yes               Mailed check           53.85        107.70
# 3               No  Bank transfer (automatic)           42.30       1903.50
# 4              Yes           Electronic check           70.70        141.40
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
telecom_data['gender'] = telecom_data['gender'].apply(lambda x: 'M' if x == 'Male' else 'F')

# %%
#grouping the tenure columns into bins
#grouping the tenure into different bins, 
#grouping those within a year into 1-12months, those within 2yrs into 12-24months and so on
labels = list("{}-{}".format(i, i + 11) for i in range(1, 72, 12))
telecom_data['tenure_group'] = pd.cut(telecom_data.tenure, range(1, 80, 12), right=False, labels=labels)
telecom_data
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG      F              0     Yes         No       1
# 1     5575-GNVDE      M              0      No         No      34
# 2     3668-QPYBK      M              0      No         No       2
# 3     7795-CFOCW      M              0      No         No      45
# 4     9237-HQITU      F              0      No         No       2
# ...          ...    ...            ...     ...        ...     ...
# 7038  6840-RESVB      M              0     Yes        Yes      24
# 7039  2234-XADUH      F              0     Yes        Yes      72
# 7040  4801-JZAZL      F              0     Yes        Yes      11
# 7041  8361-LTMKD      M              1     Yes         No       4
# 7042  3186-AJIEK      M              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# 1              No              Yes          No          No              No
# 2             Yes               No          No          No              No
# 3              No              Yes         Yes          No              No
# 4              No               No          No          No              No
# ...           ...              ...         ...         ...             ...
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn tenure_group
# 0              29.85         29.85    No         1-12
# 1              56.95       1936.30    No        25-36
# 2              53.85        107.70   Yes         1-12
# 3              42.30       1903.50    No        37-48
# 4              70.70        141.40   Yes         1-12
# ...              ...           ...   ...          ...
# 7038           84.80       2035.20    No        13-24
# 7039          103.20       7430.40    No        61-72
# 7040           29.60        325.60    No         1-12
# 7041           74.40        297.60   Yes         1-12
# 7042          105.65       6972.90    No        61-72
#
# [7032 rows x 22 columns]

# %%
telecom_data.drop(columns=['telecom_group'], inplace =True)

# %%
maximum = telecom_data.sort_values('tenure', ascending=False)
maximum
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 2988  6295-OSINB      M              0     Yes         No      72
# 3823  9065-ZCPQX      M              0     Yes         No      72
# 3886  3786-WOVKF      F              1     Yes         No      72
# 6659  3967-KXAPS      M              0     Yes         No      72
# 6661  3704-IEAXF      F              0     Yes        Yes      72
# ...          ...    ...            ...     ...        ...     ...
# 3852  7291-CDTMJ      M              0      No         No       1
# 474   9399-APLBT      F              0     Yes        Yes       1
# 1371  6567-HOOPW      F              1      No         No       1
# 1373  4291-HPAXL      M              0      No        Yes       1
# 0     7590-VHVEG      F              0     Yes         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 2988          Yes               Yes     Fiber optic                  Yes
# 3823          Yes               Yes             DSL                  Yes
# 3886          Yes               Yes     Fiber optic                  Yes
# 6659          Yes               Yes             DSL                  Yes
# 6661           No  No phone service             DSL                   No
# ...           ...               ...             ...                  ...
# 3852          Yes                No              No  No internet service
# 474           Yes                No     Fiber optic                   No
# 1371          Yes                No     Fiber optic                   No
# 1373          Yes                No              No  No internet service
# 0              No  No phone service             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 2988                  Yes                  Yes                   No
# 3823                  Yes                  Yes                  Yes
# 3886                  Yes                   No                   No
# 6659                  Yes                  Yes                  Yes
# 6661                  Yes                   No                  Yes
# ...                   ...                  ...                  ...
# 3852  No internet service  No internet service  No internet service
# 474                   Yes                   No                   No
# 1371                   No                   No                   No
# 1373  No internet service  No internet service  No internet service
# 0                     Yes                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 2988                  Yes                  Yes        Two year
# 3823                   No                  Yes        Two year
# 3886                  Yes                  Yes        One year
# 6659                  Yes                  Yes        Two year
# 6661                  Yes                  Yes        Two year
# ...                   ...                  ...             ...
# 3852  No internet service  No internet service  Month-to-month
# 474                    No                   No  Month-to-month
# 1371                  Yes                   No  Month-to-month
# 1373  No internet service  No internet service  Month-to-month
# 0                      No                   No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 2988              Yes           Electronic check          109.65
# 3823               No  Bank transfer (automatic)           78.85
# 3886              Yes  Bank transfer (automatic)          106.85
# 6659               No    Credit card (automatic)           92.30
# 6661               No    Credit card (automatic)           53.65
# ...               ...                        ...             ...
# 3852              Yes  Bank transfer (automatic)           19.65
# 474               Yes           Electronic check           74.70
# 1371              Yes           Electronic check           79.20
# 1373               No               Mailed check           19.85
# 0                 Yes           Electronic check           29.85
#
#       TotalCharges Churn tenure_group
# 2988       7894.80    No        61-72
# 3823       5677.20    No        61-72
# 3886       7693.20    No        61-72
# 6659       6645.60    No        61-72
# 6661       3862.80    No        61-72
# ...            ...   ...          ...
# 3852         19.65    No         1-12
# 474          74.70   Yes         1-12
# 1371         79.20   Yes         1-12
# 1373         19.85    No         1-12
# 0            29.85    No         1-12
#
# [7032 rows x 22 columns]

# %%
telecom_data.to_csv('cleaned_teleco_data.csv')
